# %%
# %load_ext autoreload
# %autoreload 2

import modules.utils as utils
modelLoads= ["AA", "AB", "BA", "BB", "infer2018"]
weightModels= ["identical"]
randomGraphs= ["ER", "BA", "WS", "GEO"]
seeds= [10, 11, 12, 13, 14]
strains= [1, 2, 3, 4]

# %%
# folder_to_reset = "results"
# utils.reset_folder(folder_to_reset, "archive")
# folder_to_reset = "logs"
# utils.reset_folder(folder_to_reset, "archive_logs")
#utils.empty_folder("log")

# %%
#utils.rename_file("test.sh", "test250.sh")
for randomGraph in randomGraphs:
    for strain in [1, 2, 3, 4]:
        cosines= 0
        spectrals= 0
        edges= 0
        jaccards= 0
        for seed in seeds:
            fileName= f"results/AA/AA_{randomGraph}_identical_{seed}_{strain}_0_140000.npz"
            fileNameNew= f"results/AA/AA_{randomGraph}_identical_{seed}_{strain}_0_8_50_{0.01*1000}_140000.npz"
            utils.rename_file(fileName, fileNameNew)
# Out:
# Error: File results/AA/AA_ER_identical_10_1_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_11_1_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_12_1_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_13_1_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_14_1_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_10_2_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_11_2_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_12_2_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_13_2_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_14_2_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_10_3_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_11_3_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_12_3_0_140000.npz not found.
# Error: File results/AA/AA_ER_identical_13_3_0_140000.npz not found.
# ...
